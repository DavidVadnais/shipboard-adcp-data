# %% [markdown]
# Overview
#
# The [Hawaii Ocean Time-series](https://hahana.soest.hawaii.edu/hot/) project involves cruises to Station ALOHA nearly every month, starting in October 1988. Most of these cruises have been on ships equipped with acoustic Doppler current profilers, the observations from which are presented here. Continuous time series of currents at ALOHA are available elsewhere from the WHOTS mooring.
#
# The goal of this Notebook is to download the ADCP data from the [UHDAS-HOTS website](https://currents.soest.hawaii.edu/hot/index.html) so that users can more easily use this data to preform science.

# %%
# Imports
import requests
#import netCDF4 as nc
import io
from bs4 import BeautifulSoup
import os

# %%
# Functions
def download_file(url, save_path):
    # Send a GET request to the URL
    response = requests.get(url)
    
    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Write the content to a file in the specified path
        with open(save_path, 'wb') as file:
            file.write(response.content)
        print(f"File downloaded successfully and saved to {save_path}")
    else:
        print(f"Failed to download file. Status code: {response.status_code}")

# %%
# Fetch the webpage
url = "https://currents.soest.hawaii.edu/hot/global_list/0/index.html"
response = requests.get(url)
html_content = response.content

# Parse the webpage with BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Find all rows containing cruise and sonar info
rows = soup.find_all('tr')[1:]  # Skip header row

# Extract cruise names and sonar details
cruise_sonar_pairs = []
for row in rows:
    cols = row.find_all('td')
    cruise_name = cols[1].text.strip()
    sonar_info = cols[5].text.strip()  # sonar info is in the 5th column
    cruise_sonar_pairs.append([cruise_name, sonar_info])
    #print(f"Cruise Name: {cruise_name}, Sonar: {sonar_info}")


front = 'https://currents.soest.hawaii.edu/hot/downloads/'
os.mkdir('data')

for pair in cruise_sonar_pairs:
    url = f"{front}{pair[1]}"
    print(url)
    save_path = f"data/{pair[1]}"
    download_file(url, save_path)
# Out:
# https://currents.soest.hawaii.edu/hot/downloads/hot001.tar.gz
# File downloaded successfully and saved to data/hot001.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot002.tar.gz
# File downloaded successfully and saved to data/hot002.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot003.tar.gz
# File downloaded successfully and saved to data/hot003.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot005.tar.gz
# File downloaded successfully and saved to data/hot005.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot011.tar.gz
# File downloaded successfully and saved to data/hot011.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot012.tar.gz
# File downloaded successfully and saved to data/hot012.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot013.tar.gz
# File downloaded successfully and saved to data/hot013.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot016.tar.gz
# File downloaded successfully and saved to data/hot016.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot018.tar.gz
# File downloaded successfully and saved to data/hot018.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot020.tar.gz
# File downloaded successfully and saved to data/hot020.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot022.tar.gz
# File downloaded successfully and saved to data/hot022.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot023.tar.gz
# File downloaded successfully and saved to data/hot023.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot024.tar.gz
# File downloaded successfully and saved to data/hot024.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot025.tar.gz
# File downloaded successfully and saved to data/hot025.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot026.tar.gz
# File downloaded successfully and saved to data/hot026.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot027.tar.gz
# File downloaded successfully and saved to data/hot027.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot028.tar.gz
# File downloaded successfully and saved to data/hot028.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot029.tar.gz
# File downloaded successfully and saved to data/hot029.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot030.tar.gz
# File downloaded successfully and saved to data/hot030.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot031.tar.gz
# File downloaded successfully and saved to data/hot031.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot032.tar.gz
# File downloaded successfully and saved to data/hot032.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot033.tar.gz
# File downloaded successfully and saved to data/hot033.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot034.tar.gz
# File downloaded successfully and saved to data/hot034.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot035.tar.gz
# File downloaded successfully and saved to data/hot035.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot036.tar.gz
# File downloaded successfully and saved to data/hot036.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot037.tar.gz
# File downloaded successfully and saved to data/hot037.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot038.tar.gz
# File downloaded successfully and saved to data/hot038.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot039.tar.gz
# File downloaded successfully and saved to data/hot039.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot040.tar.gz
# File downloaded successfully and saved to data/hot040.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot041.tar.gz
# File downloaded successfully and saved to data/hot041.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot044.tar.gz
# File downloaded successfully and saved to data/hot044.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot046.tar.gz
# File downloaded successfully and saved to data/hot046.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot047.tar.gz
# File downloaded successfully and saved to data/hot047.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot049.tar.gz
# File downloaded successfully and saved to data/hot049.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot050.tar.gz
# File downloaded successfully and saved to data/hot050.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot051.tar.gz
# File downloaded successfully and saved to data/hot051.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot052.tar.gz
# File downloaded successfully and saved to data/hot052.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot053.tar.gz
# File downloaded successfully and saved to data/hot053.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot054.tar.gz
# File downloaded successfully and saved to data/hot054.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot055.tar.gz
# File downloaded successfully and saved to data/hot055.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot056.tar.gz
# File downloaded successfully and saved to data/hot056.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot057.tar.gz
# File downloaded successfully and saved to data/hot057.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot058.tar.gz
# File downloaded successfully and saved to data/hot058.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot059.tar.gz
# File downloaded successfully and saved to data/hot059.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot060.tar.gz
# File downloaded successfully and saved to data/hot060.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot061.tar.gz
# File downloaded successfully and saved to data/hot061.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot062.tar.gz
# File downloaded successfully and saved to data/hot062.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot063.tar.gz
# File downloaded successfully and saved to data/hot063.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot065.tar.gz
# File downloaded successfully and saved to data/hot065.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot066.tar.gz
# File downloaded successfully and saved to data/hot066.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot067.tar.gz
# File downloaded successfully and saved to data/hot067.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot068.tar.gz
# File downloaded successfully and saved to data/hot068.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot069.tar.gz
# File downloaded successfully and saved to data/hot069.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot070.tar.gz
# File downloaded successfully and saved to data/hot070.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot071.tar.gz
# File downloaded successfully and saved to data/hot071.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot072.tar.gz
# File downloaded successfully and saved to data/hot072.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot073.tar.gz
# File downloaded successfully and saved to data/hot073.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hotac1.tar.gz
# File downloaded successfully and saved to data/hotac1.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot074.tar.gz
# File downloaded successfully and saved to data/hot074.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot075.tar.gz
# File downloaded successfully and saved to data/hot075.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot076.tar.gz
# File downloaded successfully and saved to data/hot076.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot077.tar.gz
# File downloaded successfully and saved to data/hot077.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot078.tar.gz
# File downloaded successfully and saved to data/hot078.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot079.tar.gz
# File downloaded successfully and saved to data/hot079.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hota1a.tar.gz
# File downloaded successfully and saved to data/hota1a.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot080.tar.gz
# File downloaded successfully and saved to data/hot080.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot081.tar.gz
# File downloaded successfully and saved to data/hot081.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot082.tar.gz
# File downloaded successfully and saved to data/hot082.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot083.tar.gz
# File downloaded successfully and saved to data/hot083.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hota1b2a.tar.gz
# File downloaded successfully and saved to data/hota1b2a.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot084.tar.gz
# File downloaded successfully and saved to data/hot084.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hotac2.tar.gz
# File downloaded successfully and saved to data/hotac2.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot085.tar.gz
# File downloaded successfully and saved to data/hot085.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot086.tar.gz
# File downloaded successfully and saved to data/hot086.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot087.tar.gz
# File downloaded successfully and saved to data/hot087.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hota2b.tar.gz
# File downloaded successfully and saved to data/hota2b.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot088.tar.gz
# File downloaded successfully and saved to data/hot088.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hota3a.tar.gz
# File downloaded successfully and saved to data/hota3a.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot089.tar.gz
# File downloaded successfully and saved to data/hot089.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot090.tar.gz
# File downloaded successfully and saved to data/hot090.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot091.tar.gz
# File downloaded successfully and saved to data/hot091.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot092.tar.gz
# File downloaded successfully and saved to data/hot092.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hota3b.tar.gz
# File downloaded successfully and saved to data/hota3b.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hota4a.tar.gz
# File downloaded successfully and saved to data/hota4a.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot093.tar.gz
# File downloaded successfully and saved to data/hot093.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot094.tar.gz
# File downloaded successfully and saved to data/hot094.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot095.tar.gz
# File downloaded successfully and saved to data/hot095.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot096.tar.gz
# File downloaded successfully and saved to data/hot096.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot097.tar.gz
# File downloaded successfully and saved to data/hot097.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot098.tar.gz
# File downloaded successfully and saved to data/hot098.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hota4b.tar.gz
# File downloaded successfully and saved to data/hota4b.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot099.tar.gz
# File downloaded successfully and saved to data/hot099.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hota5a.tar.gz
# File downloaded successfully and saved to data/hota5a.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot100.tar.gz
# File downloaded successfully and saved to data/hot100.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot101.tar.gz
# File downloaded successfully and saved to data/hot101.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot102.tar.gz
# File downloaded successfully and saved to data/hot102.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot103.tar.gz
# File downloaded successfully and saved to data/hot103.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot104.tar.gz
# File downloaded successfully and saved to data/hot104.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot105.tar.gz
# File downloaded successfully and saved to data/hot105.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hota6a.tar.gz
# File downloaded successfully and saved to data/hota6a.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot106.tar.gz
# File downloaded successfully and saved to data/hot106.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot107.tar.gz
# File downloaded successfully and saved to data/hot107.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot108.tar.gz
# File downloaded successfully and saved to data/hot108.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot109.tar.gz
# File downloaded successfully and saved to data/hot109.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hota7a.tar.gz
# File downloaded successfully and saved to data/hota7a.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot110.tar.gz
# File downloaded successfully and saved to data/hot110.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot111.tar.gz
# File downloaded successfully and saved to data/hot111.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot112.tar.gz
# File downloaded successfully and saved to data/hot112.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot113.tar.gz
# File downloaded successfully and saved to data/hot113.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot114.tar.gz
# File downloaded successfully and saved to data/hot114.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot115.tar.gz
# File downloaded successfully and saved to data/hot115.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot116.tar.gz
# File downloaded successfully and saved to data/hot116.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hota8a.tar.gz
# File downloaded successfully and saved to data/hota8a.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot117.tar.gz
# File downloaded successfully and saved to data/hot117.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot118.tar.gz
# File downloaded successfully and saved to data/hot118.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot119.tar.gz
# File downloaded successfully and saved to data/hot119.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot120.tar.gz
# File downloaded successfully and saved to data/hot120.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot121.tar.gz
# File downloaded successfully and saved to data/hot121.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot122.tar.gz
# File downloaded successfully and saved to data/hot122.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot123.tar.gz
# File downloaded successfully and saved to data/hot123.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot124.tar.gz
# File downloaded successfully and saved to data/hot124.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot125.tar.gz
# File downloaded successfully and saved to data/hot125.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot126.tar.gz
# File downloaded successfully and saved to data/hot126.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot127.tar.gz
# File downloaded successfully and saved to data/hot127.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot128.tar.gz
# File downloaded successfully and saved to data/hot128.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot129.tar.gz
# File downloaded successfully and saved to data/hot129.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot130.tar.gz
# File downloaded successfully and saved to data/hot130.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot131.tar.gz
# File downloaded successfully and saved to data/hot131.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot132.tar.gz
# File downloaded successfully and saved to data/hot132.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot133.tar.gz
# File downloaded successfully and saved to data/hot133.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot134.tar.gz
# File downloaded successfully and saved to data/hot134.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot135.tar.gz
# File downloaded successfully and saved to data/hot135.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot136.tar.gz
# File downloaded successfully and saved to data/hot136.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot138.tar.gz
# File downloaded successfully and saved to data/hot138.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot139.tar.gz
# File downloaded successfully and saved to data/hot139.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot140.tar.gz
# File downloaded successfully and saved to data/hot140.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot141.tar.gz
# File downloaded successfully and saved to data/hot141.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot144.tar.gz
# File downloaded successfully and saved to data/hot144.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot145.tar.gz
# File downloaded successfully and saved to data/hot145.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot147.tar.gz
# File downloaded successfully and saved to data/hot147.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot148.tar.gz
# File downloaded successfully and saved to data/hot148.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot149.tar.gz
# File downloaded successfully and saved to data/hot149.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot150.tar.gz
# File downloaded successfully and saved to data/hot150.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot151.tar.gz
# File downloaded successfully and saved to data/hot151.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot154.tar.gz
# File downloaded successfully and saved to data/hot154.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot156.tar.gz
# File downloaded successfully and saved to data/hot156.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot157.tar.gz
# File downloaded successfully and saved to data/hot157.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot158.tar.gz
# File downloaded successfully and saved to data/hot158.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot159.tar.gz
# File downloaded successfully and saved to data/hot159.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot160.tar.gz
# File downloaded successfully and saved to data/hot160.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot161.tar.gz
# File downloaded successfully and saved to data/hot161.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot163.tar.gz
# File downloaded successfully and saved to data/hot163.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot164.tar.gz
# File downloaded successfully and saved to data/hot164.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot165.tar.gz
# File downloaded successfully and saved to data/hot165.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot166.tar.gz
# File downloaded successfully and saved to data/hot166.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot167.tar.gz
# File downloaded successfully and saved to data/hot167.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot168.tar.gz
# File downloaded successfully and saved to data/hot168.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot169.tar.gz
# File downloaded successfully and saved to data/hot169.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hotha10b.tar.gz
# File downloaded successfully and saved to data/hotha10b.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hotha11a.tar.gz
# File downloaded successfully and saved to data/hotha11a.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot170.tar.gz
# File downloaded successfully and saved to data/hot170.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot171.tar.gz
# File downloaded successfully and saved to data/hot171.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot172.tar.gz
# File downloaded successfully and saved to data/hot172.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot176.tar.gz
# File downloaded successfully and saved to data/hot176.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot173.tar.gz
# File downloaded successfully and saved to data/hot173.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot174.tar.gz
# File downloaded successfully and saved to data/hot174.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot175.tar.gz
# File downloaded successfully and saved to data/hot175.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot177.tar.gz
# File downloaded successfully and saved to data/hot177.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot178.tar.gz
# File downloaded successfully and saved to data/hot178.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot179.tar.gz
# File downloaded successfully and saved to data/hot179.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot180.tar.gz
# File downloaded successfully and saved to data/hot180.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot181.tar.gz
# File downloaded successfully and saved to data/hot181.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot182.tar.gz
# File downloaded successfully and saved to data/hot182.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot183.tar.gz
# File downloaded successfully and saved to data/hot183.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot184.tar.gz
# File downloaded successfully and saved to data/hot184.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot185.tar.gz
# File downloaded successfully and saved to data/hot185.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot186.tar.gz
# File downloaded successfully and saved to data/hot186.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot187.tar.gz
# File downloaded successfully and saved to data/hot187.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot188.tar.gz
# File downloaded successfully and saved to data/hot188.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot189.tar.gz
# File downloaded successfully and saved to data/hot189.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot190.tar.gz
# File downloaded successfully and saved to data/hot190.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot191.tar.gz
# File downloaded successfully and saved to data/hot191.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot192.tar.gz
# File downloaded successfully and saved to data/hot192.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot193.tar.gz
# File downloaded successfully and saved to data/hot193.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot194.tar.gz
# File downloaded successfully and saved to data/hot194.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot195.tar.gz
# File downloaded successfully and saved to data/hot195.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot197.tar.gz
# File downloaded successfully and saved to data/hot197.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot198.tar.gz
# File downloaded successfully and saved to data/hot198.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot199.tar.gz
# File downloaded successfully and saved to data/hot199.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot200.tar.gz
# File downloaded successfully and saved to data/hot200.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot201.tar.gz
# File downloaded successfully and saved to data/hot201.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot202.tar.gz
# File downloaded successfully and saved to data/hot202.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot203.tar.gz
# File downloaded successfully and saved to data/hot203.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot204.tar.gz
# File downloaded successfully and saved to data/hot204.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot205.tar.gz
# File downloaded successfully and saved to data/hot205.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot206.tar.gz
# File downloaded successfully and saved to data/hot206.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot207.tar.gz
# File downloaded successfully and saved to data/hot207.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot208.tar.gz
# File downloaded successfully and saved to data/hot208.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot209.tar.gz
# File downloaded successfully and saved to data/hot209.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot210.tar.gz
# File downloaded successfully and saved to data/hot210.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot211.tar.gz
# File downloaded successfully and saved to data/hot211.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot212.tar.gz
# File downloaded successfully and saved to data/hot212.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot213.tar.gz
# File downloaded successfully and saved to data/hot213.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot214.tar.gz
# File downloaded successfully and saved to data/hot214.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot215.tar.gz
# File downloaded successfully and saved to data/hot215.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot216.tar.gz
# File downloaded successfully and saved to data/hot216.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot217.tar.gz
# File downloaded successfully and saved to data/hot217.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot219.tar.gz
# File downloaded successfully and saved to data/hot219.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot220.tar.gz
# File downloaded successfully and saved to data/hot220.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot221.tar.gz
# File downloaded successfully and saved to data/hot221.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot222.tar.gz
# File downloaded successfully and saved to data/hot222.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot223.tar.gz
# File downloaded successfully and saved to data/hot223.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot224.tar.gz
# File downloaded successfully and saved to data/hot224.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot225.tar.gz
# File downloaded successfully and saved to data/hot225.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot226.tar.gz
# File downloaded successfully and saved to data/hot226.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot227.tar.gz
# File downloaded successfully and saved to data/hot227.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot228.tar.gz
# File downloaded successfully and saved to data/hot228.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot229.tar.gz
# File downloaded successfully and saved to data/hot229.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot230.tar.gz
# File downloaded successfully and saved to data/hot230.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot231.tar.gz
# File downloaded successfully and saved to data/hot231.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot232.tar.gz
# File downloaded successfully and saved to data/hot232.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot233.tar.gz
# File downloaded successfully and saved to data/hot233.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot234.tar.gz
# File downloaded successfully and saved to data/hot234.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot235.tar.gz
# File downloaded successfully and saved to data/hot235.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot236.tar.gz
# File downloaded successfully and saved to data/hot236.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot238.tar.gz
# File downloaded successfully and saved to data/hot238.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot240.tar.gz
# File downloaded successfully and saved to data/hot240.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot243.tar.gz
# File downloaded successfully and saved to data/hot243.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot244.tar.gz
# File downloaded successfully and saved to data/hot244.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot245.tar.gz
# File downloaded successfully and saved to data/hot245.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot246.tar.gz
# File downloaded successfully and saved to data/hot246.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot247.tar.gz
# File downloaded successfully and saved to data/hot247.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot248.tar.gz
# File downloaded successfully and saved to data/hot248.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot249.tar.gz
# File downloaded successfully and saved to data/hot249.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot250.tar.gz
# File downloaded successfully and saved to data/hot250.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot251.tar.gz
# File downloaded successfully and saved to data/hot251.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot252.tar.gz
# File downloaded successfully and saved to data/hot252.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot253.tar.gz
# File downloaded successfully and saved to data/hot253.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot254.tar.gz
# File downloaded successfully and saved to data/hot254.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot255.tar.gz
# File downloaded successfully and saved to data/hot255.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot256.tar.gz
# File downloaded successfully and saved to data/hot256.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot257.tar.gz
# File downloaded successfully and saved to data/hot257.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot258.tar.gz
# File downloaded successfully and saved to data/hot258.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot259.tar.gz
# File downloaded successfully and saved to data/hot259.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot260.tar.gz
# File downloaded successfully and saved to data/hot260.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot261.tar.gz
# File downloaded successfully and saved to data/hot261.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot262.tar.gz
# File downloaded successfully and saved to data/hot262.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot263.tar.gz
# File downloaded successfully and saved to data/hot263.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot264.tar.gz
# File downloaded successfully and saved to data/hot264.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot265.tar.gz
# File downloaded successfully and saved to data/hot265.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot266.tar.gz
# File downloaded successfully and saved to data/hot266.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot267.tar.gz
# File downloaded successfully and saved to data/hot267.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot268.tar.gz
# File downloaded successfully and saved to data/hot268.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot269.tar.gz
# File downloaded successfully and saved to data/hot269.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot270.tar.gz
# File downloaded successfully and saved to data/hot270.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot271.tar.gz
# File downloaded successfully and saved to data/hot271.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot272.tar.gz
# File downloaded successfully and saved to data/hot272.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot273.tar.gz
# File downloaded successfully and saved to data/hot273.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot274.tar.gz
# File downloaded successfully and saved to data/hot274.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot275.tar.gz
# File downloaded successfully and saved to data/hot275.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot276.tar.gz
# File downloaded successfully and saved to data/hot276.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot277.tar.gz
# File downloaded successfully and saved to data/hot277.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot278.tar.gz
# File downloaded successfully and saved to data/hot278.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot279.tar.gz
# File downloaded successfully and saved to data/hot279.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot280.tar.gz
# File downloaded successfully and saved to data/hot280.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot281.tar.gz
# File downloaded successfully and saved to data/hot281.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot282.tar.gz
# File downloaded successfully and saved to data/hot282.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot283.tar.gz
# File downloaded successfully and saved to data/hot283.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot284.tar.gz
# File downloaded successfully and saved to data/hot284.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot285.tar.gz
# File downloaded successfully and saved to data/hot285.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot286.tar.gz
# File downloaded successfully and saved to data/hot286.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot287.tar.gz
# File downloaded successfully and saved to data/hot287.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot288.tar.gz
# File downloaded successfully and saved to data/hot288.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot289.tar.gz
# File downloaded successfully and saved to data/hot289.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot290.tar.gz
# File downloaded successfully and saved to data/hot290.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot291.tar.gz
# File downloaded successfully and saved to data/hot291.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot292.tar.gz
# File downloaded successfully and saved to data/hot292.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot293.tar.gz
# File downloaded successfully and saved to data/hot293.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot294.tar.gz
# File downloaded successfully and saved to data/hot294.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot295.tar.gz
# File downloaded successfully and saved to data/hot295.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot296.tar.gz
# File downloaded successfully and saved to data/hot296.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot297.tar.gz
# File downloaded successfully and saved to data/hot297.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot298.tar.gz
# File downloaded successfully and saved to data/hot298.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot299.tar.gz
# File downloaded successfully and saved to data/hot299.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot300.tar.gz
# File downloaded successfully and saved to data/hot300.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot301.tar.gz
# File downloaded successfully and saved to data/hot301.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot302.tar.gz
# File downloaded successfully and saved to data/hot302.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot303.tar.gz
# File downloaded successfully and saved to data/hot303.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot304.tar.gz
# File downloaded successfully and saved to data/hot304.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot305.tar.gz
# File downloaded successfully and saved to data/hot305.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot306.tar.gz
# File downloaded successfully and saved to data/hot306.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot307.tar.gz
# File downloaded successfully and saved to data/hot307.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot308.tar.gz
# File downloaded successfully and saved to data/hot308.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot309.tar.gz
# File downloaded successfully and saved to data/hot309.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot310.tar.gz
# File downloaded successfully and saved to data/hot310.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot311.tar.gz
# File downloaded successfully and saved to data/hot311.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot312.tar.gz
# File downloaded successfully and saved to data/hot312.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot313.tar.gz
# File downloaded successfully and saved to data/hot313.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot314.tar.gz
# File downloaded successfully and saved to data/hot314.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot315.tar.gz
# File downloaded successfully and saved to data/hot315.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot316.tar.gz
# File downloaded successfully and saved to data/hot316.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot317.tar.gz
# File downloaded successfully and saved to data/hot317.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot318.tar.gz
# File downloaded successfully and saved to data/hot318.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot319.tar.gz
# File downloaded successfully and saved to data/hot319.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot320.tar.gz
# File downloaded successfully and saved to data/hot320.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot321.tar.gz
# File downloaded successfully and saved to data/hot321.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot322.tar.gz
# File downloaded successfully and saved to data/hot322.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot323.tar.gz
# File downloaded successfully and saved to data/hot323.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot324.tar.gz
# File downloaded successfully and saved to data/hot324.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot325.tar.gz
# File downloaded successfully and saved to data/hot325.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot326.tar.gz
# File downloaded successfully and saved to data/hot326.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot327.tar.gz
# File downloaded successfully and saved to data/hot327.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot328.tar.gz
# File downloaded successfully and saved to data/hot328.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot329.tar.gz
# File downloaded successfully and saved to data/hot329.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot330.tar.gz
# File downloaded successfully and saved to data/hot330.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot331.tar.gz
# File downloaded successfully and saved to data/hot331.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot332.tar.gz
# File downloaded successfully and saved to data/hot332.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot333.tar.gz
# File downloaded successfully and saved to data/hot333.tar.gz
# https://currents.soest.hawaii.edu/hot/downloads/hot334.tar.gz
# File downloaded successfully and saved to data/hot334.tar.gz
